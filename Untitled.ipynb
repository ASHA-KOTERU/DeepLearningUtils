# %%
import pandas as pd

# %%
df=pd.read_csv("customer_transactions.csv")

# %%
df
# Out:
#       Unnamed: 0 customer_name transaction_id                 item_name  \
# 0              0    customer_0   customer_0_1            Nutella Waffle
# 1              1    customer_0   customer_0_1            Chicken Crispy
# 2              2    customer_0   customer_0_1                     Tacos
# 3              3    customer_0   customer_0_1                    Nachos
# 4              4    customer_0   customer_0_1     Chicken Butter Masala
# 5              5    customer_0   customer_0_1       Spicy Chicken Pizza
# 6              6    customer_0   customer_0_1        Chicken Cream Soup
# 7              7    customer_0   customer_0_2            Nutella Waffle
# 8              8    customer_0   customer_0_2  Assorted Non-Veg Platter
# 9              9    customer_0   customer_0_2            Veg Fried Rice
# 10            10    customer_0   customer_0_3            Nutella Waffle
# 11            11    customer_0   customer_0_3               Gulab Jamun
# ...
